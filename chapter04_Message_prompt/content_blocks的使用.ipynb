# %% [markdown]
# # content 理解为时数据类型，弱类型的，支持字符串和列表

# %%
from langchain_core.messages import HumanMessage

msg1 = HumanMessage(content = "你好啊")
msg2 = HumanMessage("你好啊")
print(msg1)
print(msg2)

# %% [markdown]
# # content_blocks
