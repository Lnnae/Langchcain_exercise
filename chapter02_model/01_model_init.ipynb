# %%
#调用线上模型
#deepseek pro

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_community.chat_models import ChatOpenAI
from langchain_deepseek import ChatDeepSeek
import os

load_dotenv(override=True)

#环境变量读取配置
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

deepseek_llm = ChatDeepSeek(
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,  # 注意：这里是api_base，不是base_url
    model_name="deepseek-v4-flash",
)
print(deepseek_llm.invoke("请介绍一下你自己"))

# %% [markdown]
# #对于deepseek的优化

# %%
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv

# 从.env文件中加载环境变量
# override=True 确保.env文件优先
load_dotenv(override=True)
# 创建DeepSeek LLM
deepseek_llm = ChatDeepSeek(
    model="deepseek-v4-flash",
)
print(deepseek_llm.invoke("请介绍一下你自己"))
# Out:
# content='嗨！很高兴认识你！🎉\n\n我是 **DeepSeek**，由深度求索公司创造的AI助手。简单来说，我是一个乐于助人的智能伙伴，随时准备回答你的问题、提供建议，或者陪你聊聊天。\n\n**关于我的几个亮点：**\n\n✨ **免费使用**——没错，完全免费！无论你问多少问题，我都乐意帮忙。\n\n📚 **超大上下文**——我有1M的上下文能力，可以一次性处理像《三体》三部曲那样的长篇内容，帮你分析、总结或者讨论。\n\n🌐 **联网搜索**——虽然我默认是离线状态，但你可以在Web或App上手动开启联网搜索功能，我就能获取最新信息帮你解答问题。\n\n📎 **文件处理**——我支持上传图片、PDF、Word、Excel、PPT、TXT等文件，能从中提取文字信息帮你处理。\n\n🗣️ **语音输入**——在App上，你还可以用语音和我交流，更方便快捷。\n\n📅 **知识截止**——我的知识库更新到2025年5月，所以对最近发生的事情可能不太了解，但你可以通过联网搜索让我获取最新信息。\n\n**我能帮你做什么？**\n- 解答各种问题（学习、工作、生活）\n- 写作、翻译、编程\n- 分析文档、总结内容\n- 头脑风暴、提供创意\n- 或者只是陪你聊聊天\n\n有什么我可以帮你的吗？尽管问，我会尽全力帮你！😊' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我介绍一下自己。这是一个非常常见且基础的问题，用户可能是初次接触我，想了解我的基本情况和能力范围。我需要给出一个清晰、全面且友好的自我介绍。\n\n想到了可以从几个核心方面来组织回答：先热情打招呼，然后说明我的身份和创造者。接着重点介绍我的主要能力和特点，比如文本处理、上下文长度、文件支持、联网搜索、免费性质等。最后可以说明我的知识截止日期和帮助用户的意愿，并引导用户提出进一步的问题。整体语气要热情、开放，让用户感觉亲切可信。\n\n嗯，就用一个结构化的回复，分块但自然流畅地介绍，确保信息准确，避免夸大。从“嗨！很高兴认识你！”开头，然后分点说明，但思考过程中不用列表，只需想清楚涵盖哪些关键信息点：我是谁、能做什么、有什么特色、怎么帮助用户。'} response_metadata={'token_usage': {'completion_tokens': 485, 'prompt_tokens': 7, 'total_tokens': 492, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 182, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 7}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'e4e6d5e1-61eb-4686-b477-1873200d8bea', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f1640-637e-71b2-acf4-2af552436264-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 485, 'total_tokens': 492, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 182}}

# %% [markdown]
# #通过ChatOpenAI接入deepseek

# %%
from langchain_openai import ChatOpenAI

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

deepseek_llm2 = ChatOpenAI(
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    model="deepseek-v4-flash",
)
response = deepseek_llm2.invoke("1 + 11 = ?")
print(response)

# %% [markdown]
# #接入质谱glm

# %%
from langchain_community.chat_models import ChatZhipuAI
from dotenv import load_dotenv

# override=True 确保.env文件优先
load_dotenv(override=True)
# ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")
zhipu_llm = ChatZhipuAI(
    model="glm-4.5-Air",
    # api_base=ZHIPUAI_BASE_URL, #可选
    # api_key=ZHIPUAI_API_KEY #可选
)
print(zhipu_llm.invoke("中国河北有哪些城市"))
from langchain_community.chat_models import ChatZhipuAI

# %% [markdown]
# #LangChain 1.x 统一方式 init_chat_model()

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model1 = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    #model_provider="deepseek",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
#发送数据
print(model1.invoke("鱼香肉丝的制作过程分步骤"))

# %% [markdown]
# #model_provider 表示模型的提供者，支持的providers有： anthropic , anthropic_bedrock,
# azure_ai, azure_openai, bedrockbedrock_converse, cohere, deepseek , fireworks,
# google_anthropic_vertex, google_genai, google_vertexaigrog, huggingface, ibm, mistralai, nvidia,
# ollama , openai , openrouter , perplexity, together, upstage, xai

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model1 = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
#发送数据
print(model1.invoke("鱼香肉丝的制作过程分步骤"))

# %% [markdown]
# #DeepSeek官网的DeepSeek模型：可以调用ChatDeepSeek()、ChatOpenAI()、
# init_chat_model()三种方式

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

# 从.env文件中加载环境变量
load_dotenv(override=True)
model = init_chat_model(
    # model="gpt-5.4-mini",
    model="deepseek-v4-flash",
    model_provider="deepseek",
     temperature=1.5,
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    #max_tokens=15,
)
# 向模型发送单条数据
# for i in range(3):
#     response = model.invoke("请用中文详细介绍什么是AI")
# # 打印响应
# print(response.content)
string="把helloWorld翻译成中文"
print(model.invoke(string))
# Out:
# content='"helloWorld" 翻译成中文是 **“你好世界”**。' additional_kwargs={'refusal': None, 'reasoning_content': '我们要求把"helloWorld"翻译成中文。注意"helloWorld"通常是一个编程术语，比如Java中的类名或方法名，或者是一个常见的示例程序名称。在中文里，它通常被直接翻译为"你好世界"或者"Hello World"。但这里可能需要考虑大小写和驼峰命名。如果严格翻译，应该是"你好世界"。然而，问题很简单，直接给出答案即可。'} response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 10, 'total_tokens': 113, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 86, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'a51d3896-a113-4bd5-94e2-50f365bd0842', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f141c-fc9d-7b72-8ee2-c6d29289ec62-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 103, 'total_tokens': 113, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 86}}
